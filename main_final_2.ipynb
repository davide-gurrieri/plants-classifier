# %% [markdown]
# <a href="https://colab.research.google.com/github/davide-gurrieri/plants-classifier/blob/main/main_final_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Neural Networks and Deep Learning 2023 - First Homework

# %% [markdown]
# This notebook contains the code of the final model used for the first competition.

# %%
COLAB = False
FIRST_RUN = True
MODEL_NAME = "ConvNeXtBase_Mix_4"
VISUALIZATION = True
VALIDATION = True
ONE_HOT = True
VALIDATION_PROPORTION = 0.2
NUM_CLASSES = 2
BALANCED = True
TF_DATASET = True
BOTH_CUTMIX_AND_MIXUP = False
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

# %% [markdown]
# ## Colab initialization

# %%
if COLAB:
    if FIRST_RUN:
        ## Clone the private repository in Colab
        TOKEN = "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"
        REPO_URL= "github.com/davide-gurrieri/plants-classifier.git"
        USER_NAME = "davide-gurrieri"
        USER_EMAIL = "gurrieri99@gmail.com"

        # !git clone --branch main https://oauth2:$TOKEN@$REPO_URL
        # %cd plants-classifier/
        # !git remote set-url origin  https://oauth2:$TOKEN@$REPO_URL
        # !git config user.name $USER_NAME
        # !git config user.email $USER_EMAIL
        # %cd ..
        
        # Import the data from the drive
        from google.colab import drive
        drive.mount('/content/drive')
        # Copy the data from the drive to the local repository folder
        # %cp "drive/MyDrive/[2023-2024] AN2DL/Homework 1/public_data.zip" "plants-classifier/data/"
        # Unzip the data
        # !unzip plants-classifier/data/public_data.zip -d plants-classifier/data/
        # Remove the zip file
        # !rm plants-classifier/data/public_data.zip
        # %cd plants-classifier/
        
        # Install the requirements
        # !pip install keras-cv
    else:
        # %cd plants-classifier/

# %% [markdown]
# ## Import libraries

# %% [markdown]
# Select the desired model

# %%
import models.ConvNeXtBaseCutmixMixup3 as MyModel
from models.ConvNeXtBaseCutmixMixup3 import ConvNeXtBaseCutmixMixup3 as Constructor
# Out:
# 2.14.0
# Using TensorFlow backend

# %%
from imports import *
import utils

# %% [markdown]
# ## Dataset

# %% [markdown]
# The function `utils.load_data` loads the dataset from the given path, encodes the labels and removes the outliers from the dataset.

# %%
X_train_val, y_train_val, labels, X_out, y_out, shrek, trol = utils.load_data()

print("\nShape of X_train_val: ", X_train_val.shape)
print("Shape of y_train_val: ", y_train_val.shape)
# Out:
# The dataset without outliers contains 5004 images of plants, 3101 healthy and 1903 unhealthy.
# The ratio of the healthy plants over the total is 0.62.
# Each image has shape (96, 96, 3).
# The labels encoding is: {0: 'healthy', 1: 'unhealthy'}.
#
# Shape of X_train_val:  (5004, 96, 96, 3)
# Shape of y_train_val:  (5004, 1)

# %% [markdown]
# Visualize some images and outliers.

# %%
if VISUALIZATION:
    utils.plot_images(
        X_train_val,
        y_train_val,
        num_img=50,
        num_cols=10,
        show=True,
        save=False,
        show_label=True,
        name="first_images.pdf",
    )

# %%
if VISUALIZATION:
    utils.plot_images(
        X_out,
        y_out,
        num_img=50,
        num_cols=10,
        show=True,
        save=False,
        name="outliers.pdf",
        show_label=True,
    )

# %%
if BALANCED:
        class_weights = compute_class_weight("balanced", classes=np.unique(y_train_val[:, 0]), y=y_train_val[:, 0])
        class_weights = {0: class_weights[0], 1: class_weights[1],}

# %%
if VALIDATION:
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=SEED, test_size=VALIDATION_PROPORTION, stratify=y_train_val)
    if ONE_HOT:
        y_train = tfk.utils.to_categorical(y_train)
        y_val_standard = np.copy(y_val)
        y_val = tfk.utils.to_categorical(y_val)
else:
    if ONE_HOT:
        y_train_val = tfk.utils.to_categorical(y_train_val)

# %%
if TF_DATASET:
    
    AUTOTUNE = tf.data.AUTOTUNE
    
    if VALIDATION:
        training_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
        validation_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
        validation_dataset = validation_dataset.batch(BATCH_SIZE)
        validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)
        
    else:
        training_dataset = tf.data.Dataset.from_tensor_slices((X_train_val, y_train_val))
    
    training_dataset = training_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
    training_dataset =training_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Data augmentation for the tensorflow dataset

# %%
if TF_DATASET:
    def to_dict(image, label):
        image = tf.cast(image, tf.float32)
        if not ONE_HOT:
            label = tf.one_hot(label, NUM_CLASSES)
        return {"images": image, "labels": label}
    
    cut_mix = keras_cv.layers.CutMix()
    mix_up = keras_cv.layers.MixUp()

    def cut_mix_or_mix_up(samples):
        if tf.random.uniform(()) > 0.5:
            samples = cut_mix(samples)
        else:
            samples = mix_up(samples)
        return samples

    def cut_mix_and_mix_up(samples):
        samples = cut_mix(samples)
        samples = mix_up(samples)
        return samples
    
    def preprocess_for_model(inputs):
        images, labels = inputs["images"], inputs["labels"]
        images = tf.cast(images, tf.float32)
        return images, labels

    training_dataset = training_dataset.map(to_dict).map(cut_mix_and_mix_up if BOTH_CUTMIX_AND_MIXUP else cut_mix_or_mix_up).map(preprocess_for_model)

# %% [markdown]
# ## Training

# %% [markdown]
# Create an object of the custom model class

# %%
if BALANCED:
    MyModel.fit_param_1["class_weight"] = class_weights
model_obj = Constructor(MODEL_NAME,
                        MyModel.build_param_1,
                        MyModel.compile_param_1,
                        MyModel.fit_param_1,)

# %% [markdown]
# Build and compile the model

# %%
model_obj.build()
model_obj.compile()
model_obj.model.summary()
# Out:
# Model: "ConvNeXtBase_Mix_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  augmentation (Sequential)   (None, 96, 96, 3)         0
#
#  convnext_base (Functional)  (None, 3, 3, 1024)        87566464
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dropout (Dropout)           (None, 9216)              0
#
#  dense (Dense)               (None, 1024)              9438208
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Output (Dense)              (None, 2)                 1026
#
# =================================================================
# Total params: 97530498 (372.05 MB)
# Trainable params: 9964034 (38.01 MB)
# Non-trainable params: 87566464 (334.04 MB)
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
if VALIDATION:
    if TF_DATASET:
        model_obj.train_val(x_train=training_dataset, x_val=validation_dataset)
    else:
        model_obj.train_val(X_train, y_train, X_val, y_val)
else:
    if TF_DATASET:
        model_obj.train(x_train=training_dataset)
    else:
        model_obj.train(X_train_val, y_train_val)

# %% [markdown]
# Save the model as `saved_model/MODEL_NAME` and also in the drive (Colab case).

# %%
model_obj.save_model()
if COLAB:
    # %cd ..
    # %cp -r "/content/plants-classifier/saved_models/MODEL_NAME" "drive/MyDrive/"
    # %cd plants-classifier/

# %% [markdown]
# ## Performance evaluation

# %% [markdown]
# Plot the training history

# %%
if VALIDATION:
    model_obj.plot_history()

# %% [markdown]
# Evaluate the model on the validation set

# %%
if VALIDATION:
    if TF_DATASET:
        evaluation_dataset = tf.data.Dataset.from_tensor_slices(X_val)
        evaluation_dataset = evaluation_dataset.batch(BATCH_SIZE)
    else :
        evaluation_dataset = X_val
    model_obj.evaluate(evaluation_dataset, np.squeeze(y_val_standard))

# %% [markdown]
# ## Second training

# %% [markdown]
# Create another object of the custom model class

# %%
if BALANCED:
    MyModel.fit_param_2["class_weight"] = class_weights
model_obj_2 = Constructor(MODEL_NAME + "_fine_tuning",
                        MyModel.build_param_1,
                        MyModel.compile_param_2,
                        MyModel.fit_param_2,
                        starting_model=model_obj.model)

# %% [markdown]
# Unfreeze all the layers

# %%
model_obj_2.unfreeze_layers()
model_obj_2.model.summary()
# Out:
# Model: "ConvNeXtBase_Mix"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  convnext_base (Functional)  (None, 1024)              87566464
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 1000)              1025000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_1 (Dense)             (None, 500)               500500
#
#  dropout_2 (Dropout)         (None, 500)               0
#
#  Output (Dense)              (None, 2)                 1002
#
# =================================================================
# Total params: 89092966 (339.86 MB)
# Trainable params: 1526502 (5.82 MB)
# Non-trainable params: 87566464 (334.04 MB)
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
if VALIDATION:
    if TF_DATASET:
        model_obj_2.train_val(x_train=training_dataset, x_val=validation_dataset)
    else:
        model_obj_2.train_val(X_train, y_train, X_val, y_val)
else:
    if TF_DATASET:
        model_obj_2.train(x_train=training_dataset)
    else:
        model_obj_2.train(X_train_val, y_train_val)

# %% [markdown]
# Save the model as `saved_model/MODEL_NAME` and also in the drive (Colab case).

# %%
model_obj_2.save_model()
if COLAB:
    # %cd ..
    # %cp -r "/content/plants-classifier/saved_models/MODEL_NAME_fine_tuning" "drive/MyDrive/"
    # %cd plants-classifier/

# %% [markdown]
# ## Performance evaluation

# %% [markdown]
# Plot the training history

# %%
if VALIDATION:
    model_obj_2.plot_history()

# %% [markdown]
# Evaluate the model on the validation set

# %%
if VALIDATION:
    if TF_DATASET:
        evaluation_dataset = tf.data.Dataset.from_tensor_slices(X_val)
        evaluation_dataset = evaluation_dataset.batch(BATCH_SIZE)
    else :
        evaluation_dataset = X_val
    model_obj_2.evaluate(evaluation_dataset, np.squeeze(y_val_standard))
